# %% [markdown]
# # **INTRODUCTION**

# %% [markdown]
# In this part of the activity you will learn and experiment hands-on experience with the basic  **'iris'**  dataset. and eventually working on your first ever Machine Learning Algorithm.

# %% [markdown]
# **THEME**

# %% [markdown]
# IRIS dataset consists of data related to flowers of species 'setosa' and 'versicolor', the core task is to identify the the Petal Width based on  the given input data consisting of Sepal width and length, Petal Length.

# %% [markdown]
# **DATA ACQUISITION**

# %%
import pandas as pd

# %%
#loading the iris dataset
dataframe = pd.read_csv('kc_house_data.csv')

# %% [markdown]
# **DATA EXPLORATION**

# %%
#displaying the top 5 rows of the dataset
dataframe.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
dataframe = dataframe.drop('id',axis=1)

# %% [markdown]
# **SUMMARY STATISTICS**

# %%
dataframe.describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.401822e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.673622e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    waterfront          view     condition         grade  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       1.494309      0.007542      0.234303      3.409430      7.656873
# ...

# %% [markdown]
# **FEATURES AND LABEL**

# %%
#label variable
target =dataframe['price']

#feature variable
features = dataframe[['bedrooms','bathrooms','sqft_living','view','condition','sqft_lot','floors','waterfront','grade','sqft_above','sqft_basement','yr_built','yr_renovated','zipcode','lat','long','sqft_living15'
,'sqft_lot15']]

# %%
target.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %%
features.head()
# Out:
#    bedrooms  bathrooms  sqft_living  view  condition  sqft_lot  floors  \
# 0         3       1.00         1180     0          3      5650     1.0
# 1         3       2.25         2570     0          3      7242     2.0
# 2         2       1.00          770     0          3     10000     1.0
# 3         4       3.00         1960     0          5      5000     1.0
# 4         3       2.00         1680     0          3      8080     1.0
#
#    waterfront  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0           0      7        1180              0      1955             0
# 1           0      7        2170            400      1951          1991
# 2           0      6         770              0      1933             0
# 3           0      7        1050            910      1965             0
# 4           0      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %% [markdown]
# **DATA VISUALIZATION**

# %%
import seaborn as sns

# %%
sns.pairplot(data,diag_kind="kde")

# %% [markdown]
# **TRAIN AND TEST DATA SPLIT**

# %% [markdown]
# **THEME**
#
#
#
# The main idea is to estimate the likely performance of a model that works well on unseen data sample,which eventually helps in the determination of the sort of machine learning model to pick for a problem.
#
# We can split the data into two pieces so that the model can be trained and tested on unseen data.Then we can eventually describe that the testing accuracy is a better estimate than training accuracy upon unseen data sample performance.

# %%
# Import 'train_test_split'
from sklearn.cross_validation import train_test_split
# Shuffle and split the data into training and testing subsets
X_train, X_test, y_train, y_test = train_test_split(features,target,test_size=0.2,train_size=0.8,random_state=42)

# Success
print("Training and testing split was successful.")
# Out:
# Training and testing split was successful.

# %%
print(features)
# Out:
#                   date  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      20141013T000000         3       1.00         1180      5650     1.0
# 1      20141209T000000         3       2.25         2570      7242     2.0
# 2      20150225T000000         2       1.00          770     10000     1.0
# 3      20141209T000000         4       3.00         1960      5000     1.0
# 4      20150218T000000         3       2.00         1680      8080     1.0
# 5      20140512T000000         4       4.50         5420    101930     1.0
# 6      20140627T000000         3       2.25         1715      6819     2.0
# 7      20150115T000000         3       1.50         1060      9711     1.0
# 8      20150415T000000         3       1.00         1780      7470     1.0
# 9      20150312T000000         3       2.50         1890      6560     2.0
# 10     20150403T000000         3       2.50         3560      9796     1.0
# ...

# %% [markdown]
# **PERFORMANCE METRIC**
#
# It is difficult to measure the quality of a given model without quantifying its performance over training and testing. This is typically done using some type of performance metric, whether it is through calculating some type of error, the goodness of fit, or some other useful measurement. For this project, you will be calculating the coefficient of determination, R2, to quantify your model's performance. The coefficient of determination for a model is a useful statistic in regression analysis, as it often describes how "good" that model is at making predictions.
#
#
#
# The values for R2 range from 0 to 1, which captures the percentage of squared correlation between the predicted and actual values of the target variable. A model with an R2 of 0 is no better than a model that always predicts the mean of the target variable, whereas a model with an R2 of 1 perfectly predicts the target variable. Any value between 0 and 1 indicates what percentage of the target variable, using this model, can be explained by the features. A model can be given a negative R2 as well, which indicates that the model is arbitrarily worse than one that always predicts the mean of the target variable.

# %%
# Import 'r2_score' from scikit-learn package
from sklearn.metrics import r2_score
def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    
    # Calculate the performance score between 'y_true' and 'y_predict'
    score = r2_score(y_true,y_predict)
    
    # Return the score
    return score

# %% [markdown]
# **APPLYING YOUR FIRST MACHINE LEARNING ALGORITHM**
#
# Read the [documentation](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html) carefully.

# %%
#IMPORTING LINEAR REGRESSOR FROM SCIKIT-LEARN
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
reg_fit = regressor.fit(X_train,y_test)
reg_pred = reg_fit.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-72-b249859eaee8> in <module>()
#       2 from sklearn.linear_model import LinearRegression
#       3 regressor = LinearRegression()
# ----> 4 reg_fit = regressor.fit(X_train,y_test)
#       5 reg_pred = reg_fit.predict(X_test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     480         n_jobs_ = self.n_jobs
#     481         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 482                          y_numeric=True, multi_output=True)
#     483
#     484         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ...

# %% [markdown]
# **EVALUATE THE MODEL**

# %%
print("regression score of :", performance_metric(y_test,reg_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-6b85d1019948> in <module>()
# ----> 1 print("regression score of :", performance_metric(y_test,reg_pred))
#
# NameError: name 'performance_metric' is not defined
